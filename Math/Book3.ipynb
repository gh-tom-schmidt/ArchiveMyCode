# %%
import numpy as np
import cv2

from show import show
from CoordsShift import Coords2D

# %%
orig_img = cv2.imread('Testimage_Dog.jpg')

gray_img = cv2.cvtColor(orig_img, cv2.COLOR_BGR2GRAY)

show(gray_img)

# %%
l = Coords2D(gray_img)
show(l.deactivate())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 l = Coords2D(gray_img)
#       2 show(l.deactivate())
#
# File ~/Documents/Python/Math/CoordsShift.py:42, in Coords2D.__init__(self, d2_array)
#      40 self.d2_array = np.asarray([])
#      41 for l in d2_array:
# ---> 42     self.d2_array.append(Coords1D(l))
#      44 # the array has the size (y, x)
#      45 # [[1,2,3,4],
#      46 #  [1,2,3,4],
#      47 #  [1,2,3,4]]
#      49 self.d2_array_range = len(self.d2_array) - 1
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
a = Coords2D([[1,2,3], [4,5,6], [7,8,9]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 a = Coords2D([[1,2,3], [4,5,6], [7,8,9]])
# ----> 2 a.shift()
#       3 print(a[0])
#       4 a.unshift()
#
# TypeError: 'int' object is not callable
