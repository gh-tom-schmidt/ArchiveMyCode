# %%
import numpy as np
import matplotlib.pyplot as plt

from draw import draw

# %% [markdown]
# # Gaussian function
# https://en.wikipedia.org/wiki/Gaussian_function

# %%
def f(x):
    return np.e ** -x ** 2

# %%
draw(f)

# %%
def f(x, a=1, b=1, c=1):
    return a * np.e ** (-0.5 * (x - b) ** 2 / c ** 2)

# %%
draw(f)
