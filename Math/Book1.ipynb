# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
def draw(function, x_from=-10, x_to=10, density=100, int=False, scatter=False):

    # Generate x values
    if int:
        x_values = np.round(np.linspace(x_from, x_to, density))
    else:
        x_values = np.linspace(x_from, x_to, density)  # Generating 100 points between -10 and 10

    y_values = []

    # Calculate y values using the function
    for x in x_values:
        y_values.append(function(x))
    
    # Plot the function
    if scatter:
        plt.scatter(x_values, y_values, s=5)
    else:
        plt.plot(x_values, y_values)
    
    plt.grid(True)
    plt.show()

# %%
def show(img):
    plt.imshow(img, cmap='gray')
    plt.axis('off')  
    plt.show()

# %%
def f(x): 
    return abs(x)

# %%
def g(x):
    return 0 if x < 0 else 1

# %%
draw(g)

# %%
def f(x):
    return 1 / x if not x == 0 else None

# %%
draw(f)

# %%
y = []
for x in np.linspace(1, 0.0002, 100):
    y.append(f(x))

print(y)
# Out:
# [1.0, 1.0102020199958777, 1.0206143479820702, 1.031243554727783, 1.0420964876085252, 1.0531802853161136, 1.064502393517503, 1.0760705815346288, 1.0878929601237781, 1.0999780004399913, 1.112334554279679, 1.1249718757031075, 1.1378996441477478, 1.1511279891538162, 1.1646675168347396, 1.1785293382379203, 1.1927250997551901, 1.207267015757883, 1.2221679036487267, 1.2374412215419768, 1.2531011088046173, 1.269162429715323, 1.2856408205245415, 1.3025527402288808, 1.319915525406374, 1.3377474494966557, 1.3560677869521622, 1.374896882733795, 1.394256227677817, 1.4141685403209447, 1.4346578558386227, 1.455749622828507, 1.4774708087585664, 1.4998500149985, 1.5229176024662034, 1.5467058290499478, 1.5712490001142725, 1.5965836335663162, 1.6227486411529055, 1.6497855278813753, 1.677738611713666, 1.7066552659796375, 1.7365861872987138, 1.7675856921972697, 1.7997120460726286, 1.8330278286952175, 1.8676003410728705, 1.903502059243137, 1.940811141432201, 1.9796119960487741, 2.0199959192001633, 2.06206
# ...

# %%
draw(f, 1, 0.0002, 100)

# %%
def f(x):
    return x**2 if 0 <= x <= 5 else None

# %%
draw(f, -10, 10)

# %%
def g(n):
    return 1 / (2 * n + 1)

# %%
draw(g, 0, 100)

# %%
def h(x):
    return (-1)**(x+1) * g(x)

# %%
draw(h, 0, 100, 100, True, True)

# %%
def sum(k):
    sum = 0
    for x in range(k):
        sum = h(x)
    return sum

sum(1000)
# Out:
# 0.0005002501250625312

# %%
orig_img = cv2.imread('Testimage_Dog.jpg')

gray_img = cv2.cvtColor(orig_img, cv2.COLOR_BGR2GRAY)

show(gray_img)

# %%
gray_img.shape
# Out:
# (1335, 2000)

# %%
show(gray_img[0:500])

# %%
def f(x):
    return -x

# %%
def tranform(img):
    # y
    for i in range(img.shape[0]):
        # x
        for j in range(img.shape[1]):
            img[i][j] = f(img[i][j])
    
    return img

# %%
show(tranform(gray_img.copy()))
# Out:
# /tmp/ipykernel_17569/4014641394.py:2: RuntimeWarning: overflow encountered in scalar negative
#   return -x

# %%
def tranform(img):
    # y
    for i in range(img.shape[0]):
        # x
        for j in range(img.shape[1] // 2):
            img[i][j], img[i][img.shape[1] - 1 - j] = img[i][img.shape[1] - 1 - j], img[i][j]
    
    return img

# %%
show(tranform(gray_img.copy()))

# %%
def f(x, y):
    return round(x + np.sin(y)), round(y + np.sin(x))

# %%
f(10,10)
# Out:
# (9, 9)

# %%
def tranform(img):

    output = img.copy()
    # y
    for i in range(img.shape[0]):
        # x
        for j in range(img.shape[1]):

            x, y = f(j, i)

            output[y][x] = img[i][j]
    
    return output

# %%
show(tranform(gray_img.copy()))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 show(tranform(gray_img.copy()))
#
# Cell In[28], line 11, in tranform(img)
#       7     for j in range(img.shape[1]):
#       9         x, y = f(j, i)
# ---> 11         output[y][x] = img[i][j]
#      13 return output
#
# IndexError: index 2000 is out of bounds for axis 0 with size 2000

# %%
def N(f, df, iterations):
    x = 0
    for i in range(iterations):
        x -= f(x) / df(x)
    return x

# %%
def f(x):
    return 2 * x

# %%
def df(x):
    return 2

# %%
def ddf(x):
    return 0

# %%
draw(f)

# %%
draw(df)

# %%
draw(ddf)

# %%
def f(x):
    return x - (2*x) / 2

# %%
draw(f)

# %%
def f(x):
    return np.e ** -(x ** 2)

# %%
draw(f)

# %%
x0 = 0.11
x1 = 0.1

print(f"f({x0})= {f(x0)}, f({x1})= {f(x1)}")
abs(f(x0) - f(x1)) <= abs(x0 - x1)
# Out:
# f(0.11)= 0.9879729106308383, f(0.1)= 0.9900498337491681
# True

# %%
def df(x):
    return -2 * x * np.e ** -(x ** 2)

# %%
draw(df, x_from=-1, x_to=1, scatter=True, density=1000)

# %%
df(0)
# Out:
# 0.0

# %%
def f(x):
    return x - np.e ** (-x ** 2)

# %%
draw(f)

# %%
def df(x):
    return 1 + 2 * x * np.e ** (-x ** 2)

# %%
def N(start, interations):
    x = start
    for i in range(interations):
        x = x - (f(x) / df(x))
    
    return x

# %%
N(1, 1)
# Out:
# 0.6358246728512563

# %%
def f(x):
    return x - np.e ** (- (x ** 2))

# %%
def df(x):
    return 1 + 2 * x * np.e ** (- (x ** 2))

# %%
def N(x, iterations):
    for i in range(iterations):
        x = x - f(x) / df(x)
    return x

# %%
N(0, 1)
# Out:
# 1.0

# %%
N(0, 2)
# Out:
# 0.6358246728512563

# %%
N(0, 3)
# Out:
# 0.6529371688445919

# %%
N(0, 4)
# Out:
# 0.6529186404370338

# %%
def f(x):
    return np.e ** (- (x ** 2))

# %%
def N(x, iterations):
    for i in range(iterations):
        x = f(x)
    return x

# %%
N(0, 1)
# Out:
# 1.0

# %%
N(0, 2)
# Out:
# 0.36787944117144233

# %%
N(0, 3)
# Out:
# 0.8734230184931167

# %%
N(0, 4)
# Out:
# 0.4663271888497616
